# %%
import pandas as pd

# %%
data = pd.read_parquet('get_kline_with_factor_n_points_result.parquet')

# %%
data.loc[49]
# Out:
# time_index                                                        150
# open_time                                               1769731200000
# open_time_str                                     2026-01-30 00:00:00
# close_time                                              1769734799999
# close_time_str                                    2026-01-30 00:59:59
# open_price                                                    84604.7
# high_price                                                    84697.2
# low_price                                                     84100.0
# close_price                                                   84157.4
# volume                                                       5599.959
# factors             {'alpha1': {'prev_normalized': 0.0, 'raw_value...
# open_price_list     [86459.4, 86618.4, 86525.0, 86489.0, 86628.9, ...
# high_price_list     [86680.0, 86966.4, 86704.9, 86760.8, 87150.8, ...
# ...
